# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Week-01-Wednesday" data-toc-modified-id="Week-01-Wednesday-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Week 01 Wednesday</a></span></li><li><span><a href="#What-frameworks-can-we-use-for-A01?" data-toc-modified-id="What-frameworks-can-we-use-for-A01?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>What frameworks can we use for A01?</a></span><ul class="toc-item"><li><span><a href="#What-do-we-mean-by-&quot;Social-Implications?&quot;" data-toc-modified-id="What-do-we-mean-by-&quot;Social-Implications?&quot;-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>What do we mean by "Social Implications?"</a></span></li><li><span><a href="#What-do-we-mean-by-&quot;Environmental-Implications?&quot;" data-toc-modified-id="What-do-we-mean-by-&quot;Environmental-Implications?&quot;-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>What do we mean by "Environmental Implications?"</a></span></li><li><span><a href="#What-do-we-mean-by-&quot;Ethical-Considerations?&quot;" data-toc-modified-id="What-do-we-mean-by-&quot;Ethical-Considerations?&quot;-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>What do we mean by "Ethical Considerations?"</a></span></li></ul></li><li><span><a href="#The-IEEE-code-of-ethics....-is-it-enough?" data-toc-modified-id="The-IEEE-code-of-ethics....-is-it-enough?-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>The IEEE code of ethics.... is it enough?</a></span></li><li><span><a href="#Summary-of-ORI-framework-(just-one-that-you-could-use):" data-toc-modified-id="Summary-of-ORI-framework-(just-one-that-you-could-use):-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Summary of ORI framework (just one that you could use):</a></span></li><li><span><a href="#Break-into-groups!-Time-for-an-exercise" data-toc-modified-id="Break-into-groups!-Time-for-an-exercise-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Break into groups! Time for an exercise</a></span></li><li><span><a href="#Let's-make-the-Romi-move-together-in-Webots!" data-toc-modified-id="Let's-make-the-Romi-move-together-in-Webots!-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Let's make the Romi move together in Webots!</a></span><ul class="toc-item"><li><span><a href="#Class-Exercise:-Scope,-Construct,-Validate-a-basic-model-for-the-Romi's-motion" data-toc-modified-id="Class-Exercise:-Scope,-Construct,-Validate-a-basic-model-for-the-Romi's-motion-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Class Exercise: Scope, Construct, Validate a basic model for the Romi's motion</a></span></li><li><span><a href="#Class-Exercise:" data-toc-modified-id="Class-Exercise:-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Class Exercise:</a></span></li></ul></li><li><span><a href="#What-did-we-learn?" data-toc-modified-id="What-did-we-learn?-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>What did we learn?</a></span></li></ul></div>

# %% [markdown]
# ## Week 01 Wednesday
# August 28, 2024
#
# # Goals
#
# 1. What frameworks can we use for A01?
# 2. Ethics/Impacts/Stakeholders case study
# 3. Romi in Webots: Basic motion & models

# %% [markdown]
# ## What frameworks can we use for A01?
#
# A01 asks us to consider the social, environmental, and ethical implications of technological solutions.
#
# * What do we mean by *Social Implications?*
# * What do we mean by *Environmental Implications?*
# * What do we mean by *Ethical Implications?*

# %% [markdown]
# ### What do we mean by "Social Implications?"
#
# Aside from questions of *should* there are questions of *does*. How *does* a robot's design influence the social structures in which it operates? Let's think about these for the following
#
# * A factory robot that welds or assembles
# * A self-driving car
# * Educational social robot designed to improve conflict-resolution skills in young children
# * Educational mobile robot (like Romi)

# %% [markdown]
# ### What do we mean by "Environmental Implications?"
#
# When we talk about environmental impact of these robots, we might be talking about the world as a whole (e.g. climate change, waste accumulation, sustainability), but we are *probably* at least talking about the *natural* environment adjacent to the robot and how that might be affected by it at some point during its life cycle. What can we say about the environmental impacts of:
#
# * An ocean cleanup robot
# * A logging robot
# * A chatbot like ChatGPT
#
# Think about both *primary* and *secondary* effects each of these robots could have on its environment.

# %% [markdown]
# ###  What do we mean by "Ethical Considerations?"
#
# When we talk about "ethical considerations" in the context of engineering and robotics specifically, a lot of the time we are talking about what people (in many cases, engineers) **should do.** For example, established roboticist Rodney Brooks developed his own [Three Laws of Robotics](https://spectrum.ieee.org/rodney-brooks-three-laws-robotics?utm_source=roboticsnews&utm_medium=email&utm_campaign=roboticsnews-08-13-24&utm_content=httpsspectrumieeeorgrodneybrooksthreelawsrobotics&mkt_tok=NzU2LUdQSC04OTkAAAGU6wRC4t-QJYhh5Yg_PFOQvQdQkES1Lz_190-3UZ-1lsLwsb0hsk6KKWo1Ijp-7crxLFumMdDieVLD-pR4SYkVCuq-2I0PoDe1DcHDlRel7Zs6) that seem to govern how engineers should design and test robots before moving them towards a commercial product. But Robot Ethics can deal with many things:
#
# * How robots should behave towards (people, property, animals, plants)
# * How engineers designing robots should behave
# * How people should behave in the company of and/or towards robots
#
#
# **Let's focus in temporarily *just* on how robot *engineers* and possibly their creations should behave**.

# %% [markdown]
# ## The IEEE code of ethics.... is it enough?
# ![image.png](attachment:image.png)

# %%
# %%html
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="1000px" height="700px" src="https://openroboethics.org/wp-content/uploads/2021/07/ORI-Foresight-into-Artificial-Intelligence-Ethics-Launch-V1.pdf"> </iframe>
# Out:
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="1000px" height="700px" src="https://openroboethics.org/wp-content/uploads/2021/07/ORI-Foresight-into-Artificial-Intelligence-Ethics-Launch-V1.pdf"> </iframe>

# %% [markdown]
# ## Summary of ORI framework (just one that you could use):
#
# * Identify your robot's use case (intended or unintended or both)
# * Identify stakeholders, select key stakeholders to engage with
# * Listen to the stakeholders
# * Map "personas" of your stakeholders & identify their values
#   - Create a persona chart
#   - Consider robotics laws/principles
#   - Consider community values
# * Discover tensions in values
# * Discover tensions in activities
# * Discover tensions in technologies
# * Synthesize
#   - Organize tensions and values thematically

# %% [markdown]
# ## Break into groups! Time for an exercise
#
# Cruise [IEEE robotics news](https://spectrum.ieee.org/tag/robotics) for a key story.
#
# In groups of 3, answer the following questions. **Do some searching** to answer these questions. Don't just rely on the one story!!
#
# * What environmental impacts might this project have?
# * What social impacts might this project have?
# * What economic impacts might this project have?
# * What ethical concerns are there with the project?
# * What *stakeholders* can you identify in the article?
#     - What stakeholders may there be that are *not* mentioned?
#     - What *value tensions* can you see between stakeholders?

# %% [markdown]
# ## Let's make the Romi move together in Webots!

# %% [markdown]
# More detail is available at the video in the [02_Romi_Resources](https://alexanderallenbrown.github.io/ES302_FA24_Students/02_Romi_Resources/02A_Romi_Resource.html#Working-With-Virtual-and-Physical-Romi-Robots-in-the-Lab) page, but the steps are:

# %% [markdown]
# * Open Google Drive for Desktop on your lab station computer.
# * Navigate to your ES302_Name/ shared folder.
# * Create a new folder called "Week01_Wednesday/"
# * Right click to open a terminal at this location using windows cmd or git bash.
# * Create a new ES302 Webots workspace using the following commands:
# ```bash
# git clone https://github.com/Alexanderallenbrown/ES302_Webots.git
# cd ES302_Webots
# git submodule update --init
# git submodule update
# ```

# %% [markdown]
# * Then, open the world romi_demo.wbt in Webots!
# * "save as" the world *and* the controller to reflect today's class.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('UpCa67lEkus')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/UpCa67lEkus"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Class Exercise: Scope, Construct, Validate a basic model for the Romi's motion
# ![image.png](attachment:image.png)
# **What has to happen (in terms of inputs/commands) for the Romi to:**
# * Move forward?
# * Move backward?
# * Turn without moving forward or backward?
# **Implement a Python function that performs each of these behaviors by modifying the "controller" file in your world.

# %% [markdown]
# ### Class Exercise:
# **Modify your controller file so that the Romi travels in a perfect square shape comprising 2x2 "world squares".**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * How did you accomplish this?
# * What if the behavior needed to be even MORE complex?

# %% [markdown]
# ## What did we learn?
#
# **Complex robot behaviors require *organization*. We NEED a SYSTEM.** The system we will learn in ES302 is to organize our robot's (many) behaviors using a Finite State Machine (FSM).

# %%
# %%html
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="1000" height="5000" src="https://alexanderallenbrown.github.io/ES302_FA24_Students/03_FiniteStateMachines/03_FiniteStateMachines.html"> </iframe>
# Out:
# <iframe id="inlineFrameExample" title="Inline Frame Example" width="1000" height="5000" src="https://alexanderallenbrown.github.io/ES302_FA24_Students/03_FiniteStateMachines/03_FiniteStateMachines.html"> </iframe>
