# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Week-09-Wednesday" data-toc-modified-id="Week-09-Wednesday-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Week 09 Wednesday</a></span></li><li><span><a href="#In-Class-Exercise-2:-ArtyBot-Inverse-Kinematics" data-toc-modified-id="In-Class-Exercise-2:-ArtyBot-Inverse-Kinematics-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>In-Class Exercise 2: ArtyBot Inverse Kinematics</a></span></li><li><span><a href="#Differential-Kinematics" data-toc-modified-id="Differential-Kinematics-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Differential Kinematics</a></span></li><li><span><a href="#Why-study-differential-kinematics?" data-toc-modified-id="Why-study-differential-kinematics?-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Why study differential kinematics?</a></span></li><li><span><a href="#Terminology-for-differential-kinematics" data-toc-modified-id="Terminology-for-differential-kinematics-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Terminology for differential kinematics</a></span></li><li><span><a href="#Forward-Differential-Kinematics" data-toc-modified-id="Forward-Differential-Kinematics-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Forward Differential Kinematics</a></span><ul class="toc-item"><li><span><a href="#Example:-Forward-Differential-Kinematics-for-a-Two-Link-Robot" data-toc-modified-id="Example:-Forward-Differential-Kinematics-for-a-Two-Link-Robot-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Example: Forward Differential Kinematics for a Two-Link Robot</a></span></li></ul></li><li><span><a href="#ArtyBot-forward-differential-kinematics" data-toc-modified-id="ArtyBot-forward-differential-kinematics-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>ArtyBot forward differential kinematics</a></span><ul class="toc-item"><li><span><a href="#Example:-Romi-Forward-Differential-Kinematics" data-toc-modified-id="Example:-Romi-Forward-Differential-Kinematics-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Example: Romi Forward Differential Kinematics</a></span></li></ul></li><li><span><a href="#Romi-Forward-Differential-Kinematics" data-toc-modified-id="Romi-Forward-Differential-Kinematics-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Romi Forward Differential Kinematics</a></span></li><li><span><a href="#Romi-Forward-Differential-Kinematics" data-toc-modified-id="Romi-Forward-Differential-Kinematics-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Romi Forward Differential Kinematics</a></span></li><li><span><a href="#Romi-Forward-Differential-Kinematics" data-toc-modified-id="Romi-Forward-Differential-Kinematics-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Romi Forward Differential Kinematics</a></span></li><li><span><a href="#Inverse-Differential-Kinematics" data-toc-modified-id="Inverse-Differential-Kinematics-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Inverse Differential Kinematics</a></span></li><li><span><a href="#Using-inverse-differential-kinematics-to-reach-a-goal-in-task-space" data-toc-modified-id="Using-inverse-differential-kinematics-to-reach-a-goal-in-task-space-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Using inverse differential kinematics to reach a goal in task space</a></span></li><li><span><a href="#Exercise:-Make-Romi-move-with-a-specified-forward-velocity-and-yaw-rate." data-toc-modified-id="Exercise:-Make-Romi-move-with-a-specified-forward-velocity-and-yaw-rate.-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Exercise: Make Romi move with a specified forward velocity and yaw rate.</a></span></li><li><span><a href="#Exercise:-Make-Romi-move-with-a-specified-forward-velocity-and-yaw-rate." data-toc-modified-id="Exercise:-Make-Romi-move-with-a-specified-forward-velocity-and-yaw-rate.-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Exercise: Make Romi move with a specified forward velocity and yaw rate.</a></span></li></ul></div>

# %% [markdown]
# ## Week 09 Wednesday
# Wednesday, March 25, 2026
#
# **Announcements**
# * A07 assigned
# * A05 feedback returned for those who submitted properly.
# * A04, A06 feedback coming soon
#
# **Goals**
# * Class exercises: Arty IK "box", Romi Differential IK

# %% [markdown]
# .
#
# .
#
# .

# %% [markdown]
# ## In-Class Exercise 2: ArtyBot Inverse Kinematics
#
# In the ArtyBot webots world, implement the inverse kinematic equations we derived in class.
#
# 1. Draw a box using ArtyBot
# 2. Build a FSM and program to draw any arbitrary shape separated by lists of points in the XY (allocentric) plane using Arty. Program should read a text file that describes what it needs to draw.
# 		○ File should have 3 columns: Drawing (boolean),	X (m)	Y (m)
# 		○ FSM should lift pen if "Drawing" column contains a 0, and should place pen on paper when "Drawing" column contains a 1.

# %% [markdown]
# **HINTS for exercise 2.1**
# * Above the loop:
#   * define a box by xy points (an array)
#       - points = np.array([[.08, 0],[.08,.02],[.1,0.02],[.1,0.0]])
#       - Define a "box point index" variable starting at 0 that you will increment to draw the "next" point in your array.
#   * Define a FSM timer that represents how long to "dwell" on any one commanded point. Don't need a whole FSM for exercise 1, but you will for exercise 2.
# * In the loop:
#   * Update timer so that it's enabled if its status bit isn't true. This will create an "auto-firing" timer that continuously resets itself at a known interval
#   * When the timer status bit goes true, increment the "box point index" variable by 1
#   * If you've gone through all the points, reset this index to 0.
#   * Now use your IK formula to find theta1, theta2
#   * Now convert theta1,theta2 to servo angles
#   * Then send servo angles to robot.
#   * Plot GPS pen position and "box points" together

# %% [markdown]
# ## Exercise: Make Romi move with a specified forward velocity and yaw rate.

# %% [markdown]
# If we wanted Romi to move in a circle of radius $R$ at some foward speed $U$, we could compute a goal yaw rate for the robot as:
#
# \begin{equation}
# \psi_g = \frac{U}{R}
# \end{equation}
#
# This means that we could specify a "goal" for the Romi's body-fixed task space as:
#
# \begin{equation}
# \vec{q}_g = \begin{bmatrix}^B\dot{x}_g & ^B\dot{y}_g & ^B\dot{\psi}_g\end{bmatrix}=\begin{bmatrix}U & 0 &  \frac{U}{R}\end{bmatrix}
# \end{equation}
#
# Then, we could make the Romi achieve this goal in its "body-fixed task space" by moving its wheels at:
#
# \begin{equation}
# \vec{q} = \begin{bmatrix}\omega_R \\ \omega_L\end{bmatrix} = \underbrace{\begin{bmatrix} \frac{R_w}{2} & -\frac{R_w}{2} \\ 0 & 0 \\\frac{R_w}{2r} & -\frac{R_w}{2r} \end{bmatrix}^+}_{J^+}\underbrace{\begin{bmatrix}U - ^B\dot{x} \\ 0 - ^B\dot{y} \\  \frac{U}{R}-^B\dot{\psi}\end{bmatrix}}_{\vec{e}}
# \end{equation}

# %% [markdown]
# ## Exercise: Make Romi move with a specified forward velocity and yaw rate.

# %% [markdown]
# In the Week09_World in Webots, implement inverse differential kinematics as shown above to achieve any given yaw rate and any given forward speed. There is a "Starter Controller" in that world for your use. You will need to:
# * Calculate wheel speeds
# * compute yaw rate
# * compute forward Romi speed
# * Compute the Jacobian
# * Compute the pseudoinverse of the Jacobian
# * Compute wheel speeds needed to achieve the desired yaw rate and forward velocity, ultimately achieving your goal turn radius $R$.
#
# Finally, use the supervisor to compare Romi's actual motion with your goal for its motion.
